# %% [markdown]
# # Importando

# %%
import pandas as pd

# %% [markdown]
# # Dataset de exemplo

# %%
import numpy as np

np.random.seed(42)

df = pd.DataFrame({
    'idade': np.random.randint(18, 65, size=100),
    'salario': np.random.normal(3000, 750, size=100).round(2),
    'valor': np.random.randint(10, 100, size=100),
    'sexo': np.random.choice(['Masculino', 'Feminino'], size=100),
    'classe': np.random.choice(['A', 'B', 'C'], size=100)
})

# %% [markdown]
# # Gráfico de linhas

# %%
df[['idade', 'salario']].plot(figsize=(8, 4), title='Idade e Salário ao longo do índice')
# Out:
# <Axes: title={'center': 'Idade e Salário ao longo do índice'}>

# %% [markdown]
# # Gráfico de barras

# %%
df_ordenado = df.sort_values('classe', ascending=True)
df_ordenado['classe'].value_counts().plot(kind='bar', title='Frequência por Classe')
# Out:
# <Axes: title={'center': 'Frequência por Classe'}, xlabel='classe'>

# %% [markdown]
# # Gráfico de pizza

# %%
df['sexo'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Distribuição por Sexo')
# Out:
# <Axes: title={'center': 'Distribuição por Sexo'}, ylabel='count'>

# %%
df['classe'].value_counts().plot(kind='pie',autopct='%1.1f%%', title='Distribuição por classe')
# Out:
# <Axes: title={'center': 'Distribuição por classe'}, ylabel='count'>

# %% [markdown]
# # Histograma

# %%
df['salario'].plot(kind='hist', bins=15, color='skyblue', edgecolor='black', title='Distribuição de Salários')
# Out:
# <Axes: title={'center': 'Distribuição de Salários'}, ylabel='Frequency'>

# %% [markdown]
# # Boxplop gerado de uma série

# %%
df['valor'].plot(kind='box', title='Boxplot de Valores')
# Out:
# <Axes: title={'center': 'Boxplot de Valores'}>

# %% [markdown]
# # Area

# %%
df[['idade', 'valor']].plot(kind='area', stacked=False)
# Out:
# <Axes: >
